# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.ensemble import RandomForestRegressor
import seaborn as sns
import matplotlib.pyplot as plt

data = pd.read_csv('data/petrol_consumption.csv')
data.head(5)
# Out:
#    Petrol_tax  Average_income  Paved_Highways  Population_Driver_licence(%)  \
# 0         9.0            3571            1976                         0.525
# 1         9.0            4092            1250                         0.572
# 2         9.0            3865            1586                         0.580
# 3         7.5            4870            2351                         0.529
# 4         8.0            4399             431                         0.544
#
#    Petrol_Consumption
# 0                 541
# 1                 524
# 2                 561
# 3                 414
# 4                 410

# %%
cor = data.corr()

# %%
fig = plt.figure(figsize=(10,16))

plt.subplot(4,2,1)
plt.grid()
plt.hist(data['Average_income'],color= 'green')
plt.xlabel('Average_income')
plt.ylabel('Number of Records')
plt.title('Before Standard Scaling',fontsize=20,color='red',weight='bold')

plt.subplot(4,2,2)
plt.grid()
plt.hist(X['Average_income'])
plt.xlabel('Average_income')
plt.ylabel('Number of Records')
plt.title('After Standard Scaling',fontsize=20,color='red',weight='bold')

plt.subplot(4,2,3)
plt.grid()
plt.hist(data['Petrol_tax'],color= 'green')
plt.xlabel('Petrol_tax')
plt.ylabel('Number of Records')


plt.subplot(4,2,4)
plt.grid()
plt.hist(X['Petrol_tax'])
plt.xlabel('Petrol_tax')
plt.ylabel('Number of Records')



plt.subplot(4,2,5)
plt.grid()
plt.hist(data['Paved_Highways'],color= 'green')
plt.xlabel('Paved_Highways')
plt.ylabel('Number of Records')


plt.subplot(4,2,6)
plt.grid()
plt.hist(X['Paved_Highways'])
plt.xlabel('Paved_Highways')
plt.ylabel('Number of Records')


plt.subplot(4,2,7)
plt.grid()
plt.hist(data['Population_Driver_licence(%)'],color= 'green')
plt.xlabel('Population_Driver_licence(%)')
plt.ylabel('Number of Records')


plt.subplot(4,2,8)
plt.grid()
plt.hist(X['Population_Driver_licence(%)'])
plt.xlabel('Population_Driver_licence(%)')
plt.ylabel('Number of Records')

plt.tight_layout(pad=4.0)
plt.title
# Out:
# <function matplotlib.pyplot.title(label, fontdict=None, loc='center', pad=None, **kwargs)>

# %%
plt.figure(figsize=(10,10))
sns.heatmap(cor)

# %%
X = data.iloc[:,0:4]
Y = data.iloc[:,4]

# %%
X.head(3)
# Out:
#    Petrol_tax  Average_income  Paved_Highways  Population_Driver_licence(%)
# 0         9.0            3571            1976                         0.525
# 1         9.0            4092            1250                         0.572
# 2         9.0            3865            1586                         0.580

# %%
Y.head(3)
# Out:
# 0    541
# 1    524
# 2    561
# Name: Petrol_Consumption, dtype: int64

# %%
ss = StandardScaler()
col = X.columns
X=ss.fit_transform(X)
X = pd.DataFrame(X,columns=col)
train_X, test_X,train_Y, test_Y = train_test_split(X,Y,test_size=0.2)

# %%
rfr = RandomForestRegressor()
rfr.fit(train_X,train_Y)
y_pred = rfr.predict(test_X)

# %%
from sklearn import metrics
import numpy as np

print('Mean Absolute Error:', metrics.mean_absolute_error(test_Y, y_pred))
print('Mean Squared Error:', metrics.mean_squared_error(test_Y, y_pred))
print('Root Mean Squared Error:', np.sqrt(metrics.mean_squared_error(test_Y, y_pred)))
# Out:
# Mean Absolute Error: 40.60700000000001
# Mean Squared Error: 2955.2332700000015
# Root Mean Squared Error: 54.36205726423533
